# %% [markdown]
# # Project description:
#
# Dr. Zeus has gathered some data from 1000 patients that have diabetes in a timespan of a year. The data has several columns depicting various information regarding how they are managing their condition.
#
# - 'Kolku dolgo e dijabeticar' - a column depicting (in years) the length of the condition that the patient has had,
#
#
# - 'Kolku mu e tromesechen (hemoglobin A1C) she4er' - a column depicting the last measured value of the hemoglobin A1C sugar levels every three months.,
#
#
# - 'Dali e na insulin ili na tabli?' - information whether a patient is on insulin (value 1) or tablets (value 0),
#
#
# - 'Glukoza (momentalna) vo krv' - information about current glucose level,
#
#
# - 'Dali ima dijabetesna retinopatija?' - information whether the patient has (value 1) or does not have (value 0) diabetic retinopathy.
#
#     ## What needs to be done?
#
#
# - 1. In the Drive folder you have a dataset 'Diabetes_data.csv', read the dataset into Pandas.
#
#
# - 2. The data is slopily gathered and you need to rename, correct, and handle missing values. Check to see if any of the columns have null/missing values and determine the best strategy for cleaning up the data (including not doing anything). ..........(3 points total)
#
#
# - 3. Find the patient which currently has the highest glucose level. Sketch (on a plot of your choice) all of the patients glucose levels and describe the plot. Draw a conclusion on how the data behaves. .......... (3 points)
#
#
# - 4. Find the average number of hemoglobin A1C levels of patients per length of disease. Which duration of the disease has the highest average glucose levels? Sketch the data on a plot of your choice to best describe the data. Write a sentence or two describing how the data behaves.   .......... (3 points)
#
#
# - 5. Find the average duration of the disease for patients that are on insulin and patients that are on tablets. Compare the results. Which method that the patients use shows better results? .......... (3 points)
#
#
# - 6. A normal hemoglobin A1C glucose level is below 5.7. Divide the data in 2 groups (patients that have normal A1C level and patients that have elevated A1C level), then sketch the data using a plot of your choice dependent on the length of the disease. Distinguishing both groups. .......... (4 points)
#
#
# - 7. How do factors influence the outcome whether a patient will have (or not) diabetic retinopathy? Analyse whether there is a correlation or not between diabetic retinopathy and other data in the set. Do this by separating the patients into 2 groups and analyzing the characteristics of the groups with respect to various information. Plot various data points if possible. .......... (4 points)

# %% [markdown]
# ### Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ova cisto mi e za proverka 

import sys
# 7fffffff, False
print("%x" % sys.maxsize, sys.maxsize > 2**32)
# Out:
# 7fffffffffffffff True

# %% [markdown]
# ### 1. In the Drive folder you have a dataset 'Diabetes_data.csv', read the dataset into Pandas.

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\Brainster\4.Python\Week 5 day 5 - PYTHON FINAL PROJECT\01 Medicine Scenario\Diabetes_data.csv')
df
# Out:
#      Unnamed: 0  Kolku dolgo e dijabeticar  \
# 0             0                        3.0
# 1             1                       40.0
# 2             2                       38.0
# 3             3                       16.0
# 4             4                       17.0
# ..          ...                        ...
# 995         995                       25.0
# 996         996                       44.0
# 997         997                       42.0
# 998         998                       29.0
# 999         999                       13.0
#
#      Kolku mu e tromesechen (hemoglobin A1C) she4er  \
# 0                                          9.522692
# 1                                          6.397994
# 2                                          7.079202
# 3                                          4.400294
# 4                                          4.746816
# ..                                              ...
# 995                                        8.890070
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Unnamed: 0                                      1000 non-null   int64
#  1   Kolku dolgo e dijabeticar                       979 non-null    float64
#  2   Kolku mu e tromesechen (hemoglobin A1C) she4er  973 non-null    float64
#  3   Dali e na insulin ili na tabli?                 988 non-null    float64
#  4   Glukoza (momentalna) vo krv                     986 non-null    float64
#  5   Dali ima dijabetesna retinopatija?              970 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
df.describe()
# Out:
#         Unnamed: 0  Kolku dolgo e dijabeticar  \
# count  1000.000000                 979.000000
# mean    499.500000                  22.618999
# std     288.819436                  12.584068
# min       0.000000                   1.000000
# 25%     249.750000                  12.000000
# 50%     499.500000                  23.000000
# 75%     749.250000                  33.000000
# max     999.000000                  44.000000
#
#        Kolku mu e tromesechen (hemoglobin A1C) she4er  \
# count                                      973.000000
# mean                                         6.529193
# std                                          2.029222
# min                                          0.686627
# 25%                                          5.159465
# 50%                                          6.472753
# 75%                                          7.972329
# max                                         12.447229
#
# ...

# %%
for col in df.columns:
    print(f'{col}:{df[col].isnull().sum()}')
# Out:
# Unnamed: 0:0
# Kolku dolgo e dijabeticar:21
# Kolku mu e tromesechen (hemoglobin A1C) she4er:27
# Dali e na insulin ili na tabli?:12
# Glukoza (momentalna) vo krv:14
# Dali ima dijabetesna retinopatija?:30

# %%
# moze i na ovoj nacin da se vidat null -ovite

df.isnull().sum()
# Out:
# Unnamed: 0                                         0
# Kolku dolgo e dijabeticar                         21
# Kolku mu e tromesechen (hemoglobin A1C) she4er    27
# Dali e na insulin ili na tabli?                   12
# Glukoza (momentalna) vo krv                       14
# Dali ima dijabetesna retinopatija?                30
# dtype: int64

# %%
# gledam null-ovite kolku procenutalno gi ima

for col in df.columns:
    print(f'{col}:{df[col].isnull().sum()/len(df[col])*100}')
# Out:
# Unnamed: 0:0.0
# Kolku dolgo e dijabeticar:2.1
# Kolku mu e tromesechen (hemoglobin A1C) she4er:2.7
# Dali e na insulin ili na tabli?:1.2
# Glukoza (momentalna) vo krv:1.4000000000000001
# Dali ima dijabetesna retinopatija?:3.0

# %%
df.rename(columns = {'Unnamed: 0':'Patient No.','Kolku dolgo e dijabeticar':'How Long is a Diabetic', 'Kolku mu e tromesechen (hemoglobin A1C) she4er':'First-trimester (hemoglobin A1C) sugar',
                              'Dali e na insulin ili na tabli?':'Insulin or pills?','Glukoza (momentalna) vo krv':'Glucose (current) in the blood','Dali ima dijabetesna retinopatija?':'Does he have diabetic retinopathy?'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Patient No.                             1000 non-null   int64
#  1   How Long is a Diabetic                  979 non-null    float64
#  2   First-trimester (hemoglobin A1C) sugar  973 non-null    float64
#  3   Insulin or pills?                       988 non-null    float64
#  4   Glucose (current) in the blood          986 non-null    float64
#  5   Does he have diabetic retinopathy?      970 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
# df['How Long is a Diabetic'].unique()
# df['First-trimester (hemoglobin A1C) sugar'].unique()
# df['Insulin or pills?'].unique()
# df['Glucose (current) in the blood'].unique()
df['Does he have diabetic retinopathy?'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2. The data is slopily gathered and you need to rename, correct, and handle missing values. Check to see if any of the columns have null/missing values and determine the best strategy for cleaning up the data (including not doing anything).

# %%
df['How Long is a Diabetic'].fillna(df['How Long is a Diabetic'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Patient No.                             1000 non-null   int64
#  1   How Long is a Diabetic                  1000 non-null   float64
#  2   First-trimester (hemoglobin A1C) sugar  973 non-null    float64
#  3   Insulin or pills?                       988 non-null    float64
#  4   Glucose (current) in the blood          986 non-null    float64
#  5   Does he have diabetic retinopathy?      970 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
df['First-trimester (hemoglobin A1C) sugar'].fillna(df['First-trimester (hemoglobin A1C) sugar'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Patient No.                             1000 non-null   int64
#  1   How Long is a Diabetic                  1000 non-null   float64
#  2   First-trimester (hemoglobin A1C) sugar  1000 non-null   float64
#  3   Insulin or pills?                       988 non-null    float64
#  4   Glucose (current) in the blood          986 non-null    float64
#  5   Does he have diabetic retinopathy?      970 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
df['Insulin or pills?'].fillna(df['Insulin or pills?'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Patient No.                             1000 non-null   int64
#  1   How Long is a Diabetic                  1000 non-null   float64
#  2   First-trimester (hemoglobin A1C) sugar  1000 non-null   float64
#  3   Insulin or pills?                       1000 non-null   float64
#  4   Glucose (current) in the blood          986 non-null    float64
#  5   Does he have diabetic retinopathy?      970 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
df['Glucose (current) in the blood'].fillna(df['Glucose (current) in the blood'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Patient No.                             1000 non-null   int64
#  1   How Long is a Diabetic                  1000 non-null   float64
#  2   First-trimester (hemoglobin A1C) sugar  1000 non-null   float64
#  3   Insulin or pills?                       1000 non-null   float64
#  4   Glucose (current) in the blood          1000 non-null   float64
#  5   Does he have diabetic retinopathy?      970 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
df['Does he have diabetic retinopathy?'].fillna(df['Does he have diabetic retinopathy?'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Patient No.                             1000 non-null   int64
#  1   How Long is a Diabetic                  1000 non-null   float64
#  2   First-trimester (hemoglobin A1C) sugar  1000 non-null   float64
#  3   Insulin or pills?                       1000 non-null   float64
#  4   Glucose (current) in the blood          1000 non-null   float64
#  5   Does he have diabetic retinopathy?      1000 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %% [markdown]
# ### 3. Find the patient which currently has the highest glucose level. Sketch (on a plot of your choice) all of the patients glucose levels and describe the plot. Draw a conclusion on how the data behaves.

# %%
highest_glucose_level =df['Glucose (current) in the blood'][df['Glucose (current) in the blood'].idxmax()]
print (f'The patient with the highest glucose level is: {highest_glucose_level}')
# Out:
# The patient with the highest glucose level is: 12.598831418508324

# %%
highest_glucose_level = df['Glucose (current) in the blood'].idxmax()
print (f'The patient with the highest glucose level with index is: {highest_glucose_level}')
# Out:
# The patient with the highest glucose level with index is: 664

# %%
df.round({'Glucose (current) in the blood':0})
# Out:
#      Patient No.  How Long is a Diabetic  \
# 0              0                     3.0
# 1              1                    40.0
# 2              2                    38.0
# 3              3                    16.0
# 4              4                    17.0
# ..           ...                     ...
# 995          995                    25.0
# 996          996                    44.0
# 997          997                    42.0
# 998          998                    29.0
# 999          999                    13.0
#
#      First-trimester (hemoglobin A1C) sugar  Insulin or pills?  \
# 0                                  9.522692                0.0
# 1                                  6.397994                0.0
# 2                                  7.079202                0.0
# 3                                  4.400294                1.0
# 4                                  4.746816                1.0
# ..                                      ...                ...
# ...

# %%
plt.figure(figsize=(20,10))
y=sns.histplot(x='Glucose (current) in the blood', data=df, bins=12, shrink=.9,stat='count',kde = True,color='red',)
y.bar_label(y.containers[0])
plt.title('Patient with glucose (current) in the blood')
plt.xlabel('Glucose (current) in the blood')
plt.ylabel('Patient No.')
plt.show()

# %%
# Spored prikazaniot plot moze da se zakluci deka najgolem broj od pacientite, odnosno 189 od niv pripagaat vo
# grupa so 6 mmol/L glikoza vo krvta, 185 pacienti se so 7 mmol/L  i 182 so 5 mmol/L.

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df,x= 'Patient No.', y='Glucose (current) in the blood',color = 'red')
plt.title('Patient with glucose (current) in the blood')
plt.show()

# %% [markdown]
# ### 4. Find the average number of hemoglobin A1C levels of patients per length of disease. Which duration of the disease has the highest average glucose levels? Sketch the data on a plot of your choice to best describe the data. Write a sentence or two describing how the data behaves.

# %%
df.groupby(['How Long is a Diabetic'])['First-trimester (hemoglobin A1C) sugar'].mean()
# Out:
# How Long is a Diabetic
# 1.0     6.522417
# 2.0     7.030744
# 3.0     6.469350
# 4.0     6.313919
# 5.0     5.496091
# 6.0     6.685249
# 7.0     6.025845
# 8.0     6.186536
# 9.0     6.201363
# 10.0    6.025771
# 11.0    6.146007
# 12.0    6.418065
# 13.0    6.491200
# 14.0    6.128044
# 15.0    6.532798
# 16.0    6.149398
# 17.0    6.486472
# 18.0    7.121592
# 19.0    6.433299
# 20.0    6.301194
# 21.0    5.383029
# 22.0    6.110047
# 23.0    6.797437
# 24.0    6.189554
# 25.0    6.900875
# 26.0    6.368538
# 27.0    6.248007
# 28.0    5.409775
# 29.0    6.198604
# 30.0    7.779622
# 31.0    6.309078
# 32.0    5.747996
# 33.0    6.882989
# 34.0    7.297670
# 35.0    6.845715
# 36.0    5.283679
# 37.0    6.790170
# 38.0    6.262221
# 39.0    6.203978
# 40.0    6.197326
# 41.0    6.407787
# 42.0    6.507374
# 43.0    6.055123
# 44.0    6.461770
# Name: First-trimester (hemoglobin A1C) sugar, dtype: float64

# %%
duration_of_the_disease = df.groupby(['How Long is a Diabetic'])['First-trimester (hemoglobin A1C) sugar'].mean().sort_values(ascending=False).idxmax()        
print (f'Duration of the disease has the highest average glucose level is: {duration_of_the_disease}')
# Out:
# Duration of the disease has the highest average glucose level is: 30.0

# %%
highest_average_glucose_levels = df.groupby(['How Long is a Diabetic'])['First-trimester (hemoglobin A1C) sugar'].mean().max()   
print (f'Highest average glucose level is: {highest_average_glucose_levels}')
# Out:
# Highest average glucose level is: 7.779621901158905

# %%
plt.figure(figsize=(20,10))
y= sns.barplot(data=df, x = 'How Long is a Diabetic', y='First-trimester (hemoglobin A1C) sugar',color = 'orange')
y.bar_label(y.containers[0])
plt.title('Patient with first-trimester (hemoglobin A1C) sugar')
plt.show()

# %%
# Prosecniot broj na nivo na hemoglobin A1C, po vremetraenje na sostojbata sto gi imale pacientite, variraat od 5,28 do 7,77%
# dodeka vremetraenjeto na bolesta sto ja imale bila od 1 godina do 44. Najzastapen prosecen hemoglobin A1C e so priblizno 6%,
# pa so priblizno 7% hemoglobin A1C i najmalku zastapeni se so 5% hemoglobin A1C.

# %% [markdown]
# ### 5. Find the average duration of the disease for patients that are on insulin and patients that are on tablets. Compare the results. Which method that the patients use shows better results?

# %%
df.groupby(['Insulin or pills?'])['How Long is a Diabetic'].mean().round(decimals=2)
# Out:
# Insulin or pills?
# 0.0    22.61
# 1.0    23.41
# Name: How Long is a Diabetic, dtype: float64

# %%
plt.figure(figsize=(20,5))
y=sns.barplot(data=df, x='Insulin or pills?', y = 'How Long is a Diabetic',hue ='Insulin or pills?')
for container in y.containers:
    y.bar_label(container)
plt.title('Insulin vs Pills')
plt.ylabel('How Long is a Diabetic')
plt.xlabel('Insulin and Pills')
plt.legend(loc='lower center')
plt.show()

# %%
df['Insulin or pills?'].value_counts()
# Out:
# 1.0    521
# 0.0    479
# Name: Insulin or pills?, dtype: int64

# %%
data = df['Insulin or pills?'].value_counts()
explode = (0.1,0.1)
data.plot (kind='pie',autopct = "%0.1f%%",explode =explode)
# Out:
# <AxesSubplot:ylabel='Insulin or pills?'>

# %%
# Spored rezultatite od analizata,vremetraenje na sostojbata sto ja imale pacientite tretirani so inslulin (1), bila podobra
# vo odnos na pacientite sto bile tretirani so tableti (0). Nivniot soodnos e 22,61 so tableti i 23,41 so insulin.
# Bidejki tretiranite pacienti so insulin imaat pogolema zastita na organizmot, od onie koi se lekuvaat so tableti, 
# pa i od tuka moze da se zakluci deka pacientite tretirani se insulin pokazuvaat podobri rezultati.

# %% [markdown]
# ### 6. A normal hemoglobin A1C glucose level is below 5.7. Divide the data in 2 groups (patients that have normal A1C level and patients that have elevated A1C level), then sketch the data using a plot of your choice dependent on the length of the disease. Distinguishing both groups.

# %%
patient_with_normal_A1C = df[(df['First-trimester (hemoglobin A1C) sugar'] <=5.7)]

# %%
patient_with_elevated_A1C = df[(df['First-trimester (hemoglobin A1C) sugar'] >5.7)]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
patient_with_normal_A1C.plot.scatter(x='How Long is a Diabetic', y='First-trimester (hemoglobin A1C) sugar', c='seagreen',label='patient_with_normal_A1C', ax=ax)
patient_with_elevated_A1C.plot.scatter(x='How Long is a Diabetic', y='First-trimester (hemoglobin A1C) sugar',c='crimson',label='patient_with_elevated_A1C', ax=ax)
plt.title('Patient with normal A1C vs Patient with elevated A1C')
plt.xlabel('How Long is a Diabetic')
plt.ylabel('First-trimester (hemoglobin A1C) sugar')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.set_style("whitegrid")
sns.boxplot(x='How Long is a Diabetic', y='First-trimester (hemoglobin A1C) sugar', data=patient_with_normal_A1C)
sns.boxplot(x='How Long is a Diabetic', y='First-trimester (hemoglobin A1C) sugar', data=patient_with_elevated_A1C)
plt.title('Patient_with_normal_A1C vs Patient_with_elevated_A1C')
plt.xlabel('How Long is a Diabetic')
plt.ylabel('First-trimester (hemoglobin A1C) sugar')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. How do factors influence the outcome whether a patient will have (or not) diabetic retinopathy? Analyse whether there is a correlation or not between diabetic retinopathy and other data in the set. Do this by separating the patients into 2 groups and analyzing the characteristics of the groups with respect to various information. Plot various data points if possible.

# %%
df['Does he have diabetic retinopathy?'].value_counts()
# Out:
# 0.0    529
# 1.0    471
# Name: Does he have diabetic retinopathy?, dtype: int64

# %%
plt.figure(figsize=(20,10))
y = sns.countplot(x="How Long is a Diabetic", hue="Does he have diabetic retinopathy?", data=df)
for container in y.containers:
    y.bar_label(container)
plt.title('Does he have diabetic retinopathy or not')
plt.show()

# %%
# Spored prikazaniot plot,mozeme da zaklucime deka pacientot sto poveke godini ima dijabet, poveke e verojatno istiot
# da dobie i dijabeticna retinopatija, no sepak istoto zavisi i od mnogu drugi faktori, kako na primer kolku 
# samiot organizam e osteten od visokata glikoza vo krvta,kolku istiot e otporen i na sekoj pacient vlijae razlicno.

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x="Does he have diabetic retinopathy?", y="Glucose (current) in the blood", data=df)
plt.title('Diabetic retinopathy vs Glucose in the blood ')
plt.show()

# %%
# Spored prikazaniot plot mozeme da zaklucime deka glukolzata vo krvta na pacientot vo zavisnot od toa dali ke dobie ili 
# ne dijabeticna retinopatija se dvizi okolu 6,1 mmol/L, no sepak i tuka istoto zavisi od mnogu drugi faktori, kako na primer kolku 
# samiot organizam e osteten od visokata glikolza vo krvta,kolku istiot e otporen i na sekoj pacient vlijae razlicno.
